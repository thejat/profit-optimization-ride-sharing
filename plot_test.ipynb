# %%
# %matplotlib notebook
from plotter import *
import time
print time.ctime()
data = get_data('../../../Xharecost_MS_annex/plot_data_test.pkl')
print time.ctime()
# Out:
# Sat Aug 13 17:08:28 2016
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-489fe186a313> in <module>()
#       3 import time
#       4 print time.ctime()
# ----> 5 data = get_data('../../../Xharecost_MS_annex/plot_data_test.pkl')
#       6 print time.ctime()
#
# D:\Dropbox\XhareCost-MS\code\plotter.pyc in get_data(filepath)
#      70         deltaP = numpy.zeros((len(data['GAMMA_ARRAY']),len(data['COEFF_ARRAY_INTERNAL_COINS'])))
#      71         for x,v in enumerate(data['GAMMA_ARRAY']):
# ---> 72             deltaP[x,] = data['profit_by_gamma'][x]['median']
#      73         #print deltaP
#      74         # # a second way of doing the same
#
# ValueError: could not broadcast input array from shape (2) into shape (3)

# %%
#Function of coeff
plot_profit_vs_probability(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Function of gamma
plot_profit_vs_gamma(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_ms_vs_profit_lb(data,[0,0.05,0.11,.16])
# Out:
# <img src="data:image/png;base64,...">

# %%
#intro plot
intro_plot(data)
# Out:
# <img src="data:image/png;base64,...">
