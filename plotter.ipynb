# %%
# %matplotlib notebook
from plotter import *
data = get_data()

# %%
#Function of coeff
plot_profit_vs_probability(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Function of gamma
plot_profit_vs_gamma(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Prob as function of gamma: single instance
plot_probability_gamma(data)
# Out:
# <img src="data:image/png;base64,...">
# [[ 0.01101591  0.02019584  0.05691554  0.09363525  0.13035496  0.16707466]
#  [ 0.01468788  0.02692778  0.07588739  0.124847    0.17380661  0.22276622]
#  [ 0.01835985  0.03365973  0.09485924  0.15605875  0.21725826  0.27845777]
#  [ 0.02203182  0.04039168  0.11383109  0.1872705   0.26070991  0.33414933]
#  [ 0.02570379  0.04712362  0.13280294  0.21848225  0.30416157  0.38984088]
#  [ 0.03671971  0.06731946  0.18971848  0.3121175   0.43451652  0.55691554]]
