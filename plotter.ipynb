# %%
# %matplotlib notebook
from plotter import *
data = get_data()

# %%
#Function of coeff
plot_profit_vs_probability(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Function of gamma
plot_profit_vs_gamma(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_ms_vs_profit_lb(data)
# Out:
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-efac7c0bc659> in <module>()
# ----> 1 plot_ms_vs_profit_lb(data)
#
# D:\Dropbox\XhareCost-MS\code\plotter.py in plot_ms_vs_profit_lb(data)
#     117     ax = fig.add_subplot(111)
#     118
# --> 119     for lb_idx,lb in enumerate(lb_vector):
#     120         xs              = data['GAMMA_ARRAY']
#     121         ys              = data['min_market_share_by_profit_lb'][lb_idx,]
#
# NameError: global name 'lb_vector' is not defined

# %%
#Prob as function of gamma: single instance
plot_probability_gamma(data)
