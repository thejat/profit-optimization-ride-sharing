# %%
'''
http://www.christophlassner.de/blog/2013/08/12/Generation-of-Truncated-Gaussian-Samples/

'''
    
# %matplotlib notebook
import matplotlib.pyplot as plt
import rtnorm as rt
from scipy.stats import truncnorm as tn

import random, numpy
random.seed(1000)
numpy.random.seed(1000)

# Mazet's version
# %timeit rtvals = rt.rtnorm(-5, 5, sigma=3., size=10000)
# 10 loops, best of 3: 167 ms per loop
rtvals = rt.rtnorm(-5, 5, sigma=3., size=10000)
plt.hist(rtvals)

# Scipy version
# The parameterization is different here!
scipytn = tn(-5/3., 5/3., scale=3)
# C implementation :) -> 1000 loops, best of 3: 528 us per loop
# %timeit k = scipytn.rvs(10000)
scipyvals = scipytn.rvs(10000)
plt.hist(scipyvals,alpha=0.5)
plt.show()
# Out:
# C:\Users\q4fj4lj9\AppData\Local\Continuum\Miniconda\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# <img src="data:image/png;base64,...">

# %%
import numpy, random
#from numpy.random import uniform as rand, normal as randn, randint as randi

#from random import uniform as rand #no defaults compared to numpy
#from random import gauss as randn #no defaults compared to numpy
#from random import randint as randi #random includes high end, numpy excludes

#see
#http://docs.scipy.org/doc/numpy/reference/routines.random.html
#https://docs.python.org/2/library/random.html

# %%
numpy.zeros(3)
# Out:
# array([ 0.,  0.,  0.])

# %%
random.seed(1000)
numpy.random.seed(1000)
numpy.random.uniform(0,1,10)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import random, numpy
random.seed(1000)
numpy.random.seed(1000)

a= numpy.random.uniform(1,10,1000)
b= [random.uniform(1,10) for x in range(1000)]

# a= numpy.random.randint(1,10,1000)
# b= [random.randint(1,9) for x in range(1000)]

# a = numpy.random.normal(0,1,1000)
# b = [random.gauss(0,1) for x in range(1000)]

plt.hist(a)
plt.hist(b,alpha=0.5)
plt.show()

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import rtnorm
rtvals = 100+rtnorm.rtnorm(-5, 5, sigma=1., size=10000)
plt.hist(rtvals)
# Out:
# <img src="data:image/png;base64,...">
# (array([   13.,   146.,   690.,  1864.,  2851.,  2626.,  1350.,   384.,
#            71.,     5.]),
#  array([  96.2752826 ,   97.0498389 ,   97.82439519,   98.59895148,
#           99.37350777,  100.14806407,  100.92262036,  101.69717665,
#          102.47173294,  103.24628923,  104.02084553]),
#  <a list of 10 Patch objects>)
