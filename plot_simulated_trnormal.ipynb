# %%
# %matplotlib notebook
from plotter import *
import time
print time.ctime()
data = get_data('../../../../sharecost_ms_annex/plot_data_simulated_trnormal_all60.pkl')
print time.ctime()
# Out:
# Wed Aug 24 11:52:33 2016
# DEFAULT IS TEST DATA UNLESS SPECIFIED OTHERWISE
# Wed Aug 24 11:54:05 2016

# %%
#Function of coeff
plot_profit_vs_probability(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Function of gamma
plot_profit_vs_gamma(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_ms_vs_profit_lb(data,lb_vector=[0,.06])
# Out:
# <img src="data:image/png;base64,...">

# %%
#Prob as function of gamma: single instance
plot_probability_gamma(data)
# Out:
# NotImplementedError
