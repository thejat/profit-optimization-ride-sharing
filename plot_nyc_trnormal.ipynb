# %%
# %matplotlib notebook
from plotter import *
import time
print time.ctime()
data = get_data('../../../../sharecost_ms_annex/plot_data_nyc_trnormal_all60.pkl')
print time.ctime()
# Out:
# Thu Sep 01 19:06:45 2016
# DEFAULT IS TEST DATA UNLESS SPECIFIED OTHERWISE
# Thu Sep 01 19:06:48 2016
# C:\Users\q4fj4lj9\AppData\Local\Continuum\Miniconda\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
#Function of coeff
plot_profit_vs_probability(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Function of gamma
plot_profit_vs_gamma(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_ms_vs_profit_lb(data,[0,0.05,0.11,.16])
# Out:
# <img src="data:image/png;base64,...">

# %%
#intro plot
intro_plot(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
plot_probability_gamma(data)
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pickle
filepath='../../../../sharecost_ms_annex/plot_data_nyc_trnormal_all60.pkl'
data_multiple_instances = pickle.load(open(filepath,'rb'))
plt.hist(data_multiple_instances[0]['detour_stats']['sensitivities'])
plt.show()
print data_multiple_instances[0]['detour_stats']['alpha_op']
# Out:
# <img src="data:image/png;base64,...">
# 50
